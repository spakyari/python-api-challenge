# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from pprint import pprint
import requests
import json
from scipy.stats import linregress
import datetime

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:

    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 623

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
i = 0
City = []
Lat = []
Lng = []
Max_Temp = []
Humidity = []
Cloudiness = []
Wind_Speed = []
Country = []
Date = []

print('Beginning Data Retrieva\n------------------')

for city in cities:
    
    url = f' http://api.openweathermap.org/data/2.5/weather?q={city}&appid={weather_api_key}'
    
    print(f'Prossessing Record {i} on Set 1 | {city}')
    
    i+=1
          
    try:
          
        json = requests.get(url).json()
        
        Lat.append(json['coord']['lat'])
        Lng.append(json['coord']['lon'])
        Max_Temp.append(json['main']['temp_max'])
        Humidity.append(json['main']['humidity'])
        Cloudiness.append(json["clouds"]["all"])
        Wind_Speed.append(json["wind"]["speed"])
        Country.append(json['sys']['country'])
        Date.append(json['dt'])
        City.append(city)
          
    except KeyError:
          
        print(f'{city} not found. Skipping...')
          
print('\n------------------\nData Retrieval Complete \n------------------')
# Out:
# Beginning Data Retrieva
# ------------------
# Prossessing Record 0 on Set 1 | nizhneudinsk
# Prossessing Record 1 on Set 1 | tsihombe
# tsihombe not found. Skipping...
# Prossessing Record 2 on Set 1 | kapaa
# Prossessing Record 3 on Set 1 | mount isa
# Prossessing Record 4 on Set 1 | bengkulu
# Prossessing Record 5 on Set 1 | yellowknife
# Prossessing Record 6 on Set 1 | dikson
# Prossessing Record 7 on Set 1 | acapulco
# Prossessing Record 8 on Set 1 | ushuaia
# Prossessing Record 9 on Set 1 | longyearbyen
# Prossessing Record 10 on Set 1 | mahajanga
# Prossessing Record 11 on Set 1 | rikitea
# Prossessing Record 12 on Set 1 | bathsheba
# Prossessing Record 13 on Set 1 | bandarbeyla
# Prossessing Record 14 on Set 1 | ribeira grande
# Prossessing Record 15 on Set 1 | kungurtug
# Prossessing Record 16 on Set 1 | puerto ayora
# Prossessing Record 17 on Set 1 | upernavik
# Prossessing Record 18 on Set 1 | amderma
# amderma not found. Skipping...
# Prossessing Record 19 on Set 1 | lubu
# Prossessing Record 20 on Set 1 | vaini
# Prossessing Record 21 on Set 1 | kashmor
# Prossessing Record 22 on Set 1 | hamilton
# Prossessing Record 23 on Set 1 | hobart
# Prossessing Record 24 on Set 1 | saint anthony
# Prossessing Record 25 on Set 1 | sterling
# Prossessing Record 26 on Set 1 | adrar
# Prossessing Record 27 on Set 1 | mataura
# Prossessing Record 28 on Set 1 | jiuquan
# Prossessing Record 29 on Set 1 | chissamba
# Prossessing Record 30 on Set 1 | waipawa
# Prossessing Record 31 on Set 1 | faanui
# Prossessing Record 32 on Set 1 | shinshiro
# Prossessing Record 33 on Set 1 | jamestown
# Prossessing Record 34 on Set 1 | barentsburg
# barentsburg not found. Skipping...
# Prossessing Record 35 on Set 1 | algiers
# Prossessing Record 36 on Set 1 | busselton
# Prossessing Record 37 on Set 1 | morgan city
# Prossessing Record 38 on Set 1 | hambantota
# Prossessing Record 39 on Set 1 | sipe sipe
# Prossessing Record 40 on Set 1 | mugan
# Prossessing Record 41 on Set 1 | husavik
# Prossessing Record 42 on Set 1 | anori
# Prossessing Record 43 on Set 1 | khatanga
# Prossessing Record 44 on Set 1 | port alfred
# Prossessing Record 45 on Set 1 | borogontsy
# Prossessing Record 46 on Set 1 | atuona
# Prossessing Record 47 on Set 1 | luderitz
# Prossessing Record 48 on Set 1 | avarua
# Prossessing Record 49 on Set 1 | taolanaro
# taolanaro not found. Skipping...
# Prossessing Record 50 on Set 1 | bonfim
# Prossessing Record 51 on Set 1 | cabo san lucas
# Prossessing Record 52 on Set 1 | hilo
# Prossessing Record 53 on Set 1 | illoqqortoormiut
# illoqqortoormiut not found. Skipping...
# Prossessing Record 54 on Set 1 | rio gallegos
# Prossessing Record 55 on Set 1 | saleaula
# saleaula not found. Skipping...
# Prossessing Record 56 on Set 1 | cape town
# Prossessing Record 57 on Set 1 | weymouth
# Prossessing Record 58 on Set 1 | lagoa
# Prossessing Record 59 on Set 1 | rio grande
# Prossessing Record 60 on Set 1 | punta arenas
# Prossessing Record 61 on Set 1 | canutama
# Prossessing Record 62 on Set 1 | kankaanpaa
# Prossessing Record 63 on Set 1 | yatou
# Prossessing Record 64 on Set 1 | hithadhoo
# Prossessing Record 65 on Set 1 | cooma
# Prossessing Record 66 on Set 1 | alofi
# Prossessing Record 67 on Set 1 | batagay
# Prossessing Record 68 on Set 1 | klyuchi
# Prossessing Record 69 on Set 1 | esperance
# Prossessing Record 70 on Set 1 | albany
# Prossessing Record 71 on Set 1 | pevek
# Prossessing Record 72 on Set 1 | palimbang
# Prossessing Record 73 on Set 1 | bambous virieux
# Prossessing Record 74 on Set 1 | isangel
# Prossessing Record 75 on Set 1 | klaksvik
# Prossessing Record 76 on Set 1 | juegang
# Prossessing Record 77 on Set 1 | castro
# Prossessing Record 78 on Set 1 | loiza
# Prossessing Record 79 on Set 1 | petropavlovsk-kamchatskiy
# Prossessing Record 80 on Set 1 | leningradskiy
# Prossessing Record 81 on Set 1 | kavieng
# Prossessing Record 82 on Set 1 | new norfolk
# Prossessing Record 83 on Set 1 | nipawin
# Prossessing Record 84 on Set 1 | kaitangata
# Prossessing Record 85 on Set 1 | saint-philippe
# Prossessing Record 86 on Set 1 | san cristobal
# Prossessing Record 87 on Set 1 | homer
# Prossessing Record 88 on Set 1 | ilulissat
# Prossessing Record 89 on Set 1 | qaanaaq
# Prossessing Record 90 on Set 1 | vaitupu
# vaitupu not found. Skipping...
# Prossessing Record 91 on Set 1 | sambava
# Prossessing Record 92 on Set 1 | iqaluit
# Prossessing Record 93 on Set 1 | buchanan
# Prossessing Record 94 on Set 1 | lata
# Prossessing Record 95 on Set 1 | port lincoln
# Prossessing Record 96 on Set 1 | kavaratti
# Prossessing Record 97 on Set 1 | sioux lookout
# Prossessing Record 98 on Set 1 | norman wells
# Prossessing Record 99 on Set 1 | tura
# Prossessing Record 100 on Set 1 | bury saint edmunds
# bury saint edmunds not found. Skipping...
# Prossessing Record 101 on Set 1 | turukhansk
# Prossessing Record 102 on Set 1 | bredasdorp
# Prossessing Record 103 on Set 1 | penzance
# Prossessing Record 104 on Set 1 | hermanus
# Prossessing Record 105 on Set 1 | vuktyl
# Prossessing Record 106 on Set 1 | matara
# Prossessing Record 107 on Set 1 | honningsvag
# Prossessing Record 108 on Set 1 | laguna
# Prossessing Record 109 on Set 1 | kloulklubed
# Prossessing Record 110 on Set 1 | roma
# Prossessing Record 111 on Set 1 | udalguri
# Prossessing Record 112 on Set 1 | stornoway
# Prossessing Record 113 on Set 1 | shiyan
# Prossessing Record 114 on Set 1 | tomatlan
# Prossessing Record 115 on Set 1 | bluff
# Prossessing Record 116 on Set 1 | berlevag
# Prossessing Record 117 on Set 1 | tiksi
# Prossessing Record 118 on Set 1 | tabiauea
# tabiauea not found. Skipping...
# Prossessing Record 119 on Set 1 | saldanha
# Prossessing Record 120 on Set 1 | kahului
# Prossessing Record 121 on Set 1 | toliary
# toliary not found. Skipping...
# Prossessing Record 122 on Set 1 | sao filipe
# Prossessing Record 123 on Set 1 | port elizabeth
# Prossessing Record 124 on Set 1 | victoria
# Prossessing Record 125 on Set 1 | vao
# Prossessing Record 126 on Set 1 | caluquembe
# Prossessing Record 127 on Set 1 | cidreira
# Prossessing Record 128 on Set 1 | carnarvon
# Prossessing Record 129 on Set 1 | ratnagiri
# Prossessing Record 130 on Set 1 | wanaka
# Prossessing Record 131 on Set 1 | saint-pierre
# Prossessing Record 132 on Set 1 | quimper
# Prossessing Record 133 on Set 1 | butaritari
# Prossessing Record 134 on Set 1 | nome
# Prossessing Record 135 on Set 1 | zabol
# Prossessing Record 136 on Set 1 | shimoda
# Prossessing Record 137 on Set 1 | katsuura
# Prossessing Record 138 on Set 1 | mahebourg
# Prossessing Record 139 on Set 1 | fortuna
# Prossessing Record 140 on Set 1 | dakar
# Prossessing Record 141 on Set 1 | praia
# Prossessing Record 142 on Set 1 | vila franca do campo
# Prossessing Record 143 on Set 1 | nizhneyansk
# nizhneyansk not found. Skipping...
# Prossessing Record 144 on Set 1 | wonthaggi
# Prossessing Record 145 on Set 1 | la rioja
# Prossessing Record 146 on Set 1 | tommot
# Prossessing Record 147 on Set 1 | gusau
# Prossessing Record 148 on Set 1 | gwadar
# Prossessing Record 149 on Set 1 | saskylakh
# Prossessing Record 150 on Set 1 | kemijarvi
# Prossessing Record 151 on Set 1 | manuk mangkaw
# Prossessing Record 152 on Set 1 | egvekinot
# Prossessing Record 153 on Set 1 | arraial do cabo
# Prossessing Record 154 on Set 1 | hualmay
# Prossessing Record 155 on Set 1 | pangody
# Prossessing Record 156 on Set 1 | tanout
# Prossessing Record 157 on Set 1 | kalabo
# Prossessing Record 158 on Set 1 | bethel
# Prossessing Record 159 on Set 1 | east london
# Prossessing Record 160 on Set 1 | oranjestad
# Prossessing Record 161 on Set 1 | attawapiskat
# attawapiskat not found. Skipping...
# Prossessing Record 162 on Set 1 | gushikawa
# Prossessing Record 163 on Set 1 | san pedro
# Prossessing Record 164 on Set 1 | dawson creek
# Prossessing Record 165 on Set 1 | arlit
# Prossessing Record 166 on Set 1 | samusu
# samusu not found. Skipping...
# Prossessing Record 167 on Set 1 | okato
# Prossessing Record 168 on Set 1 | pitimbu
# Prossessing Record 169 on Set 1 | fairbanks
# Prossessing Record 170 on Set 1 | georgetown
# Prossessing Record 171 on Set 1 | kozan
# Prossessing Record 172 on Set 1 | kalmunai
# Prossessing Record 173 on Set 1 | hasaki
# Prossessing Record 174 on Set 1 | sabzevar
# Prossessing Record 175 on Set 1 | salalah
# Prossessing Record 176 on Set 1 | behbahan
# Prossessing Record 177 on Set 1 | severo-yeniseyskiy
# Prossessing Record 178 on Set 1 | barrow
# Prossessing Record 179 on Set 1 | americus
# Prossessing Record 180 on Set 1 | namibe
# Prossessing Record 181 on Set 1 | rawson
# Prossessing Record 182 on Set 1 | mount gambier
# Prossessing Record 183 on Set 1 | yabrud
# Prossessing Record 184 on Set 1 | sabang
# Prossessing Record 185 on Set 1 | kidal
# Prossessing Record 186 on Set 1 | den helder
# Prossessing Record 187 on Set 1 | zhanatas
# zhanatas not found. Skipping...
# Prossessing Record 188 on Set 1 | nikolskoye
# Prossessing Record 189 on Set 1 | lolua
# lolua not found. Skipping...
# Prossessing Record 190 on Set 1 | flin flon
# Prossessing Record 191 on Set 1 | bonavista
# Prossessing Record 192 on Set 1 | geraldton
# Prossessing Record 193 on Set 1 | moa
# Prossessing Record 194 on Set 1 | chokurdakh
# Prossessing Record 195 on Set 1 | bolshegrivskoye
# bolshegrivskoye not found. Skipping...
# Prossessing Record 196 on Set 1 | bo
# bo not found. Skipping...
# Prossessing Record 197 on Set 1 | kinlochleven
# Prossessing Record 198 on Set 1 | ligayan
# Prossessing Record 199 on Set 1 | fort nelson
# Prossessing Record 200 on Set 1 | malwan
# malwan not found. Skipping...
# Prossessing Record 201 on Set 1 | barcelos
# Prossessing Record 202 on Set 1 | wulanhaote
# wulanhaote not found. Skipping...
# Prossessing Record 203 on Set 1 | kapit
# Prossessing Record 204 on Set 1 | los llanos de aridane
# Prossessing Record 205 on Set 1 | portland
# Prossessing Record 206 on Set 1 | nuuk
# Prossessing Record 207 on Set 1 | tasiilaq
# Prossessing Record 208 on Set 1 | thompson
# Prossessing Record 209 on Set 1 | zihuatanejo
# Prossessing Record 210 on Set 1 | clyde river
# Prossessing Record 211 on Set 1 | karauzyak
# karauzyak not found. Skipping...
# Prossessing Record 212 on Set 1 | pangai
# Prossessing Record 213 on Set 1 | riverton
# Prossessing Record 214 on Set 1 | koroni
# Prossessing Record 215 on Set 1 | sistranda
# Prossessing Record 216 on Set 1 | yumen
# Prossessing Record 217 on Set 1 | mys shmidta
# mys shmidta not found. Skipping...
# Prossessing Record 218 on Set 1 | mata
# Prossessing Record 219 on Set 1 | zaterechnyy
# Prossessing Record 220 on Set 1 | verkhnevilyuysk
# Prossessing Record 221 on Set 1 | prabumulih
# Prossessing Record 222 on Set 1 | tautira
# Prossessing Record 223 on Set 1 | chuchkovo
# Prossessing Record 224 on Set 1 | marcona
# marcona not found. Skipping...
# Prossessing Record 225 on Set 1 | hirara
# Prossessing Record 226 on Set 1 | pisco
# Prossessing Record 227 on Set 1 | luanda
# Prossessing Record 228 on Set 1 | belushya guba
# belushya guba not found. Skipping...
# Prossessing Record 229 on Set 1 | torbay
# Prossessing Record 230 on Set 1 | chibombo
# Prossessing Record 231 on Set 1 | akyab
# Prossessing Record 232 on Set 1 | antofagasta
# Prossessing Record 233 on Set 1 | sentyabrskiy
# sentyabrskiy not found. Skipping...
# Prossessing Record 234 on Set 1 | bondo
# Prossessing Record 235 on Set 1 | caravelas
# Prossessing Record 236 on Set 1 | sao joao da barra
# Prossessing Record 237 on Set 1 | paamiut
# Prossessing Record 238 on Set 1 | lakes entrance
# Prossessing Record 239 on Set 1 | awjilah
# Prossessing Record 240 on Set 1 | rodeo
# Prossessing Record 241 on Set 1 | taksimo
# Prossessing Record 242 on Set 1 | seoul
# Prossessing Record 243 on Set 1 | erzurum
# Prossessing Record 244 on Set 1 | moranbah
# Prossessing Record 245 on Set 1 | woodward
# Prossessing Record 246 on Set 1 | changping
# Prossessing Record 247 on Set 1 | lebu
# Prossessing Record 248 on Set 1 | statesboro
# Prossessing Record 249 on Set 1 | nanhai
# Prossessing Record 250 on Set 1 | broken hill
# Prossessing Record 251 on Set 1 | neiafu
# Prossessing Record 252 on Set 1 | lavrentiya
# Prossessing Record 253 on Set 1 | robertsport
# Prossessing Record 254 on Set 1 | taltal
# Prossessing Record 255 on Set 1 | colmenar viejo
# Prossessing Record 256 on Set 1 | honggang
# Prossessing Record 257 on Set 1 | guerrero negro
# Prossessing Record 258 on Set 1 | angra
# angra not found. Skipping...
# Prossessing Record 259 on Set 1 | sitka
# Prossessing Record 260 on Set 1 | beloha
# Prossessing Record 261 on Set 1 | iquitos
# Prossessing Record 262 on Set 1 | brigantine
# Prossessing Record 263 on Set 1 | mao
# Prossessing Record 264 on Set 1 | kimbe
# Prossessing Record 265 on Set 1 | tuktoyaktuk
# Prossessing Record 266 on Set 1 | jiexiu
# Prossessing Record 267 on Set 1 | tumut
# Prossessing Record 268 on Set 1 | hovd
# Prossessing Record 269 on Set 1 | port macquarie
# Prossessing Record 270 on Set 1 | conselheiro pena
# Prossessing Record 271 on Set 1 | constitucion
# Prossessing Record 272 on Set 1 | grand river south east
# grand river south east not found. Skipping...
# Prossessing Record 273 on Set 1 | tamandare
# Prossessing Record 274 on Set 1 | huarmey
# Prossessing Record 275 on Set 1 | tiarei
# Prossessing Record 276 on Set 1 | sheremetyevskiy
# Prossessing Record 277 on Set 1 | grua
# Prossessing Record 278 on Set 1 | dingle
# Prossessing Record 279 on Set 1 | lorengau
# Prossessing Record 280 on Set 1 | mount hagen
# Prossessing Record 281 on Set 1 | flinders
# Prossessing Record 282 on Set 1 | tucumcari
# Prossessing Record 283 on Set 1 | chipinge
# Prossessing Record 284 on Set 1 | eldikan
# eldikan not found. Skipping...
# Prossessing Record 285 on Set 1 | vestmannaeyjar
# Prossessing Record 286 on Set 1 | urumqi
# Prossessing Record 287 on Set 1 | mwense
# Prossessing Record 288 on Set 1 | narsaq
# Prossessing Record 289 on Set 1 | nanortalik
# Prossessing Record 290 on Set 1 | marystown
# Prossessing Record 291 on Set 1 | novikovo
# Prossessing Record 292 on Set 1 | palabuhanratu
# palabuhanratu not found. Skipping...
# Prossessing Record 293 on Set 1 | lasa
# Prossessing Record 294 on Set 1 | ondjiva
# Prossessing Record 295 on Set 1 | lompoc
# Prossessing Record 296 on Set 1 | lahaina
# Prossessing Record 297 on Set 1 | tieling
# Prossessing Record 298 on Set 1 | lagos
# Prossessing Record 299 on Set 1 | bitlis
# Prossessing Record 300 on Set 1 | bubaque
# Prossessing Record 301 on Set 1 | acarau
# Prossessing Record 302 on Set 1 | lakselv
# Prossessing Record 303 on Set 1 | koboko
# Prossessing Record 304 on Set 1 | glenwood springs
# Prossessing Record 305 on Set 1 | pudozh
# Prossessing Record 306 on Set 1 | hamina
# Prossessing Record 307 on Set 1 | temaraia
# temaraia not found. Skipping...
# Prossessing Record 308 on Set 1 | ambon
# Prossessing Record 309 on Set 1 | dayong
# Prossessing Record 310 on Set 1 | puerto carreno
# Prossessing Record 311 on Set 1 | port hueneme
# Prossessing Record 312 on Set 1 | abu samrah
# Prossessing Record 313 on Set 1 | newport
# Prossessing Record 314 on Set 1 | sokoto
# Prossessing Record 315 on Set 1 | mar del plata
# Prossessing Record 316 on Set 1 | diego de almagro
# Prossessing Record 317 on Set 1 | polovinnoye
# Prossessing Record 318 on Set 1 | chuy
# Prossessing Record 319 on Set 1 | warqla
# warqla not found. Skipping...
# Prossessing Record 320 on Set 1 | garden city
# Prossessing Record 321 on Set 1 | airai
# Prossessing Record 322 on Set 1 | vanderhoof
# Prossessing Record 323 on Set 1 | porterville
# Prossessing Record 324 on Set 1 | ponta do sol
# Prossessing Record 325 on Set 1 | sao sebastiao do passe
# Prossessing Record 326 on Set 1 | cherskiy
# Prossessing Record 327 on Set 1 | karratha
# Prossessing Record 328 on Set 1 | samalaeulu
# samalaeulu not found. Skipping...
# Prossessing Record 329 on Set 1 | provideniya
# Prossessing Record 330 on Set 1 | tual
# Prossessing Record 331 on Set 1 | varzea da palma
# Prossessing Record 332 on Set 1 | soria
# Prossessing Record 333 on Set 1 | jabiru
# jabiru not found. Skipping...
# Prossessing Record 334 on Set 1 | agadez
# Prossessing Record 335 on Set 1 | avera
# Prossessing Record 336 on Set 1 | bontang
# Prossessing Record 337 on Set 1 | canico
# Prossessing Record 338 on Set 1 | saint george
# Prossessing Record 339 on Set 1 | stromness
# Prossessing Record 340 on Set 1 | dubbo
# Prossessing Record 341 on Set 1 | nueva loja
# Prossessing Record 342 on Set 1 | baykit
# Prossessing Record 343 on Set 1 | makakilo city
# Prossessing Record 344 on Set 1 | tabuk
# Prossessing Record 345 on Set 1 | jurbarkas
# Prossessing Record 346 on Set 1 | calama
# Prossessing Record 347 on Set 1 | souillac
# Prossessing Record 348 on Set 1 | bolungarvik
# bolungarvik not found. Skipping...
# Prossessing Record 349 on Set 1 | grindavik
# Prossessing Record 350 on Set 1 | pio ix
# Prossessing Record 351 on Set 1 | sola
# Prossessing Record 352 on Set 1 | morant bay
# Prossessing Record 353 on Set 1 | rizia
# Prossessing Record 354 on Set 1 | srandakan
# Prossessing Record 355 on Set 1 | naze
# Prossessing Record 356 on Set 1 | bac lieu
# Prossessing Record 357 on Set 1 | urucara
# Prossessing Record 358 on Set 1 | lydenburg
# Prossessing Record 359 on Set 1 | chamba
# Prossessing Record 360 on Set 1 | camacha
# Prossessing Record 361 on Set 1 | ixtapa
# Prossessing Record 362 on Set 1 | nishihara
# Prossessing Record 363 on Set 1 | codrington
# Prossessing Record 364 on Set 1 | celestun
# Prossessing Record 365 on Set 1 | sinnamary
# Prossessing Record 366 on Set 1 | manicore
# Prossessing Record 367 on Set 1 | marovoay
# Prossessing Record 368 on Set 1 | tokur
# Prossessing Record 369 on Set 1 | noumea
# Prossessing Record 370 on Set 1 | bachaquero
# Prossessing Record 371 on Set 1 | christchurch
# Prossessing Record 372 on Set 1 | nabire
# Prossessing Record 373 on Set 1 | aklavik
# Prossessing Record 374 on Set 1 | burica
# burica not found. Skipping...
# Prossessing Record 375 on Set 1 | ereymentau
# Prossessing Record 376 on Set 1 | candawaga
# candawaga not found. Skipping...
# Prossessing Record 377 on Set 1 | abnub
# Prossessing Record 378 on Set 1 | marzuq
# Prossessing Record 379 on Set 1 | ornskoldsvik
# Prossessing Record 380 on Set 1 | pringsewu
# Prossessing Record 381 on Set 1 | shache
# Prossessing Record 382 on Set 1 | tuatapere
# Prossessing Record 383 on Set 1 | verkhoyansk
# Prossessing Record 384 on Set 1 | jining
# Prossessing Record 385 on Set 1 | arman
# Prossessing Record 386 on Set 1 | neryungri
# Prossessing Record 387 on Set 1 | dali
# Prossessing Record 388 on Set 1 | san jeronimo
# Prossessing Record 389 on Set 1 | santa rosalia
# Prossessing Record 390 on Set 1 | kodiak
# Prossessing Record 391 on Set 1 | gat
# Prossessing Record 392 on Set 1 | ahipara
# Prossessing Record 393 on Set 1 | amapa
# Prossessing Record 394 on Set 1 | sur
# Prossessing Record 395 on Set 1 | pacific grove
# Prossessing Record 396 on Set 1 | ruatoria
# ruatoria not found. Skipping...
# Prossessing Record 397 on Set 1 | tutoia
# Prossessing Record 398 on Set 1 | carutapera
# Prossessing Record 399 on Set 1 | pangoa
# Prossessing Record 400 on Set 1 | nacala
# Prossessing Record 401 on Set 1 | hantsport
# Prossessing Record 402 on Set 1 | burnie
# Prossessing Record 403 on Set 1 | moose factory
# Prossessing Record 404 on Set 1 | hailar
# Prossessing Record 405 on Set 1 | tumannyy
# tumannyy not found. Skipping...
# Prossessing Record 406 on Set 1 | ust-tsilma
# Prossessing Record 407 on Set 1 | milkovo
# Prossessing Record 408 on Set 1 | maniitsoq
# Prossessing Record 409 on Set 1 | pizhma
# Prossessing Record 410 on Set 1 | atikokan
# Prossessing Record 411 on Set 1 | rancho palos verdes
# Prossessing Record 412 on Set 1 | abu jubayhah
# abu jubayhah not found. Skipping...
# Prossessing Record 413 on Set 1 | havre-saint-pierre
# Prossessing Record 414 on Set 1 | vyartsilya
# Prossessing Record 415 on Set 1 | coahuayana
# Prossessing Record 416 on Set 1 | apatou
# Prossessing Record 417 on Set 1 | culfa
# Prossessing Record 418 on Set 1 | alghero
# Prossessing Record 419 on Set 1 | kouqian
# Prossessing Record 420 on Set 1 | kirakira
# Prossessing Record 421 on Set 1 | thohoyandou
# Prossessing Record 422 on Set 1 | lazaro cardenas
# Prossessing Record 423 on Set 1 | teguise
# Prossessing Record 424 on Set 1 | khonuu
# khonuu not found. Skipping...
# Prossessing Record 425 on Set 1 | boda
# Prossessing Record 426 on Set 1 | north guwahati
# Prossessing Record 427 on Set 1 | nshamba
# Prossessing Record 428 on Set 1 | heidenheim
# Prossessing Record 429 on Set 1 | chara
# Prossessing Record 430 on Set 1 | karaul
# karaul not found. Skipping...
# Prossessing Record 431 on Set 1 | kiunga
# Prossessing Record 432 on Set 1 | umzimvubu
# umzimvubu not found. Skipping...
# Prossessing Record 433 on Set 1 | saryshagan
# saryshagan not found. Skipping...
# Prossessing Record 434 on Set 1 | college
# Prossessing Record 435 on Set 1 | keti bandar
# Prossessing Record 436 on Set 1 | inongo
# Prossessing Record 437 on Set 1 | quatre cocos
# Prossessing Record 438 on Set 1 | san quintin
# Prossessing Record 439 on Set 1 | acolla
# Prossessing Record 440 on Set 1 | conceicao da barra
# Prossessing Record 441 on Set 1 | wanning
# Prossessing Record 442 on Set 1 | constantine
# Prossessing Record 443 on Set 1 | santa lucia
# Prossessing Record 444 on Set 1 | shieli
# Prossessing Record 445 on Set 1 | katangli
# Prossessing Record 446 on Set 1 | vanimo
# Prossessing Record 447 on Set 1 | lukulu
# Prossessing Record 448 on Set 1 | mujiayingzi
# Prossessing Record 449 on Set 1 | marawi
# Prossessing Record 450 on Set 1 | broome
# Prossessing Record 451 on Set 1 | nauta
# Prossessing Record 452 on Set 1 | ancud
# Prossessing Record 453 on Set 1 | fairview
# Prossessing Record 454 on Set 1 | stavropol
# Prossessing Record 455 on Set 1 | yelatma
# Prossessing Record 456 on Set 1 | basco
# Prossessing Record 457 on Set 1 | vallenar
# Prossessing Record 458 on Set 1 | werda
# Prossessing Record 459 on Set 1 | grand gaube
# Prossessing Record 460 on Set 1 | muravlenko
# Prossessing Record 461 on Set 1 | saldus
# Prossessing Record 462 on Set 1 | satitoa
# satitoa not found. Skipping...
# Prossessing Record 463 on Set 1 | halifax
# Prossessing Record 464 on Set 1 | margate
# Prossessing Record 465 on Set 1 | san juan
# Prossessing Record 466 on Set 1 | wamba
# Prossessing Record 467 on Set 1 | biskamzha
# Prossessing Record 468 on Set 1 | zhigansk
# Prossessing Record 469 on Set 1 | asau
# Prossessing Record 470 on Set 1 | atambua
# Prossessing Record 471 on Set 1 | aloleng
# Prossessing Record 472 on Set 1 | kadykchan
# kadykchan not found. Skipping...
# Prossessing Record 473 on Set 1 | bodden town
# Prossessing Record 474 on Set 1 | chaochou
# chaochou not found. Skipping...
# Prossessing Record 475 on Set 1 | diedorf
# Prossessing Record 476 on Set 1 | koumac
# Prossessing Record 477 on Set 1 | talnakh
# Prossessing Record 478 on Set 1 | iisalmi
# Prossessing Record 479 on Set 1 | srivardhan
# Prossessing Record 480 on Set 1 | severo-kurilsk
# Prossessing Record 481 on Set 1 | inirida
# Prossessing Record 482 on Set 1 | santa cruz del sur
# Prossessing Record 483 on Set 1 | kupang
# Prossessing Record 484 on Set 1 | linxia
# Prossessing Record 485 on Set 1 | cabinda
# Prossessing Record 486 on Set 1 | gravdal
# Prossessing Record 487 on Set 1 | olinda
# Prossessing Record 488 on Set 1 | sakakah
# Prossessing Record 489 on Set 1 | padang
# Prossessing Record 490 on Set 1 | sarkand
# Prossessing Record 491 on Set 1 | tessalit
# Prossessing Record 492 on Set 1 | ibra
# Prossessing Record 493 on Set 1 | new port richey
# Prossessing Record 494 on Set 1 | teknaf
# Prossessing Record 495 on Set 1 | xuchang
# Prossessing Record 496 on Set 1 | kroonstad
# Prossessing Record 497 on Set 1 | kulhudhuffushi
# Prossessing Record 498 on Set 1 | meyungs
# meyungs not found. Skipping...
# Prossessing Record 499 on Set 1 | dwarka
# Prossessing Record 500 on Set 1 | santa fe
# Prossessing Record 501 on Set 1 | loreto
# Prossessing Record 502 on Set 1 | bulgan
# Prossessing Record 503 on Set 1 | zielona gora
# Prossessing Record 504 on Set 1 | cayenne
# Prossessing Record 505 on Set 1 | rocha
# Prossessing Record 506 on Set 1 | ciras
# ciras not found. Skipping...
# Prossessing Record 507 on Set 1 | general pico
# Prossessing Record 508 on Set 1 | poya
# Prossessing Record 509 on Set 1 | eldorado
# Prossessing Record 510 on Set 1 | kampot
# Prossessing Record 511 on Set 1 | fort saint john
# fort saint john not found. Skipping...
# Prossessing Record 512 on Set 1 | hobyo
# Prossessing Record 513 on Set 1 | plastun
# Prossessing Record 514 on Set 1 | graaff-reinet
# Prossessing Record 515 on Set 1 | richards bay
# Prossessing Record 516 on Set 1 | kayfan
# kayfan not found. Skipping...
# Prossessing Record 517 on Set 1 | henties bay
# Prossessing Record 518 on Set 1 | jais
# Prossessing Record 519 on Set 1 | zhangjiakou
# Prossessing Record 520 on Set 1 | reichenau
# Prossessing Record 521 on Set 1 | russellville
# Prossessing Record 522 on Set 1 | east wenatchee bench
# Prossessing Record 523 on Set 1 | ler
# Prossessing Record 524 on Set 1 | jalu
# Prossessing Record 525 on Set 1 | edd
# Prossessing Record 526 on Set 1 | progreso
# Prossessing Record 527 on Set 1 | sillod
# Prossessing Record 528 on Set 1 | tigil
# Prossessing Record 529 on Set 1 | fenoarivo atsinanana
# Prossessing Record 530 on Set 1 | mnogovershinnyy
# Prossessing Record 531 on Set 1 | cabo rojo
# Prossessing Record 532 on Set 1 | sao jose da coroa grande
# Prossessing Record 533 on Set 1 | itamaraju
# Prossessing Record 534 on Set 1 | russell
# Prossessing Record 535 on Set 1 | ayan
# Prossessing Record 536 on Set 1 | kerouane
# Prossessing Record 537 on Set 1 | kamenskoye
# kamenskoye not found. Skipping...
# Prossessing Record 538 on Set 1 | beringovskiy
# Prossessing Record 539 on Set 1 | pangnirtung
# Prossessing Record 540 on Set 1 | cap malheureux
# Prossessing Record 541 on Set 1 | kyabram
# Prossessing Record 542 on Set 1 | tsabong
# Prossessing Record 543 on Set 1 | ponta delgada
# Prossessing Record 544 on Set 1 | rosetta
# Prossessing Record 545 on Set 1 | dolbeau
# dolbeau not found. Skipping...
# Prossessing Record 546 on Set 1 | jose bonifacio
# Prossessing Record 547 on Set 1 | soyo
# Prossessing Record 548 on Set 1 | kon tum
# Prossessing Record 549 on Set 1 | emmett
# Prossessing Record 550 on Set 1 | vardo
# Prossessing Record 551 on Set 1 | ormara
# Prossessing Record 552 on Set 1 | saquena
# Prossessing Record 553 on Set 1 | la ronge
# Prossessing Record 554 on Set 1 | sinalunga
# Prossessing Record 555 on Set 1 | sivaki
# Prossessing Record 556 on Set 1 | port blair
# Prossessing Record 557 on Set 1 | tremedal
# Prossessing Record 558 on Set 1 | chapais
# Prossessing Record 559 on Set 1 | emiliano zapata
# Prossessing Record 560 on Set 1 | manali
# Prossessing Record 561 on Set 1 | ville-marie
# Prossessing Record 562 on Set 1 | shubarkuduk
# Prossessing Record 563 on Set 1 | irricana
# Prossessing Record 564 on Set 1 | bartica
# Prossessing Record 565 on Set 1 | kieta
# Prossessing Record 566 on Set 1 | ismailia
# Prossessing Record 567 on Set 1 | wattegama
# Prossessing Record 568 on Set 1 | mackay
# Prossessing Record 569 on Set 1 | lufilufi
# Prossessing Record 570 on Set 1 | altus
# Prossessing Record 571 on Set 1 | batagay-alyta
# Prossessing Record 572 on Set 1 | bereda
# Prossessing Record 573 on Set 1 | erzin
# Prossessing Record 574 on Set 1 | lac-megantic
# Prossessing Record 575 on Set 1 | dunedin
# Prossessing Record 576 on Set 1 | bargal
# bargal not found. Skipping...
# Prossessing Record 577 on Set 1 | ushumun
# Prossessing Record 578 on Set 1 | bani walid
# Prossessing Record 579 on Set 1 | terenos
# Prossessing Record 580 on Set 1 | yarada
# Prossessing Record 581 on Set 1 | ahumada
# ahumada not found. Skipping...
# Prossessing Record 582 on Set 1 | valmiera
# Prossessing Record 583 on Set 1 | palana
# Prossessing Record 584 on Set 1 | dubai
# Prossessing Record 585 on Set 1 | mackenzie
# Prossessing Record 586 on Set 1 | waddan
# Prossessing Record 587 on Set 1 | springfield
# Prossessing Record 588 on Set 1 | trairi
# Prossessing Record 589 on Set 1 | davila
# Prossessing Record 590 on Set 1 | tiznit
# Prossessing Record 591 on Set 1 | changji
# Prossessing Record 592 on Set 1 | sumbawa
# sumbawa not found. Skipping...
# Prossessing Record 593 on Set 1 | zyryanka
# Prossessing Record 594 on Set 1 | falmouth
# Prossessing Record 595 on Set 1 | warner robins
# Prossessing Record 596 on Set 1 | monforte de lemos
# Prossessing Record 597 on Set 1 | sandusky
# Prossessing Record 598 on Set 1 | kinablangan
# Prossessing Record 599 on Set 1 | hihifo
# hihifo not found. Skipping...
# Prossessing Record 600 on Set 1 | paka
# Prossessing Record 601 on Set 1 | matagami
# Prossessing Record 602 on Set 1 | slangerup
# Prossessing Record 603 on Set 1 | babanusah
# babanusah not found. Skipping...
# Prossessing Record 604 on Set 1 | manyana
# Prossessing Record 605 on Set 1 | paranavai
# Prossessing Record 606 on Set 1 | suoyarvi
# Prossessing Record 607 on Set 1 | hofn
# Prossessing Record 608 on Set 1 | ekhabi
# Prossessing Record 609 on Set 1 | alice springs
# Prossessing Record 610 on Set 1 | lakatoro
# Prossessing Record 611 on Set 1 | alta floresta
# Prossessing Record 612 on Set 1 | reutte
# Prossessing Record 613 on Set 1 | gobabis
# Prossessing Record 614 on Set 1 | veere
# Prossessing Record 615 on Set 1 | praia da vitoria
# Prossessing Record 616 on Set 1 | tawkar
# tawkar not found. Skipping...
# Prossessing Record 617 on Set 1 | cuenca
# Prossessing Record 618 on Set 1 | little current
# Prossessing Record 619 on Set 1 | aswan
# Prossessing Record 620 on Set 1 | port-gentil
# Prossessing Record 621 on Set 1 | yurty
# Prossessing Record 622 on Set 1 | grande-riviere
# grande-riviere not found. Skipping...
#
# ------------------
# Data Retrieval Complete
# ------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
my_df = pd.DataFrame({
                        'City':City,
                        'Lat':Lat,
                        'Lng':Lng,
                        'Max_Temp':Max_Temp,
                        'Humidity':Humidity,
                        'Cloudiness':Cloudiness,
                        'Wind Speed':Wind_Speed,
                        'Country':Country,
                        'Date':Date
                        })
my_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 565 entries, 0 to 564
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   City        565 non-null    object
#  1   Lat         565 non-null    float64
#  2   Lng         565 non-null    float64
#  3   Max_Temp    565 non-null    float64
#  4   Humidity    565 non-null    int64
#  5   Cloudiness  565 non-null    int64
#  6   Wind Speed  565 non-null    float64
#  7   Country     565 non-null    object
#  8   Date        565 non-null    int64
# dtypes: float64(4), int64(3), object(2)
# memory usage: 39.9+ KB

# %%
my_df.head()
# Out:
#            City    Lat     Lng  Max_Temp  Humidity  Cloudiness  Wind Speed  \
# 0  nizhneudinsk  54.91   99.03    272.08        89         100        1.68
# 1         kapaa  22.08 -159.32    293.71        88          40        3.60
# 2     mount isa -20.73  139.50    294.15        19           0        5.10
# 3      bengkulu  -3.80  102.27    297.70        87          99        1.69
# 4   yellowknife  62.46 -114.35    265.93        94         100        0.45
#
#   Country        Date
# 0      RU  1604081644
# 1      US  1604081505
# 2      AU  1604081645
# 3      ID  1604081645
# 4      CA  1604081285

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
LessHumid_df = my_df[(my_df.Humidity < 100)]
LessHumid_df.describe()
# Out:
#               Lat         Lng    Max_Temp    Humidity  Cloudiness  Wind Speed  \
# count  553.000000  553.000000  553.000000  553.000000  553.000000  553.000000
# mean    19.519910   16.491356  288.394231   70.222423   52.531646    3.660796
# std     33.015507   92.248128   12.844049   21.122557   38.316183    2.613555
# min    -54.800000 -179.170000  246.960000    1.000000    0.000000    0.150000
# 25%     -8.840000  -65.710000  279.260000   58.000000    9.000000    1.680000
# 50%     22.890000   18.720000  291.960000   74.000000   61.000000    3.060000
# 75%     46.470000  100.350000  298.560000   88.000000   90.000000    5.030000
# max     78.220000  179.320000  310.960000   99.000000  100.000000   15.420000
#
#                Date
# count  5.530000e+02
# mean   1.604082e+09
# std    1.000421e+02
# min    1.604081e+09
# 25%    1.604082e+09
# 50%    1.604082e+09
# 75%    1.604082e+09
# max    1.604082e+09

# %%
# Save to CSV 
LessHumid = LessHumid_df.to_csv('LessHumid.csv', index=False)

# %%
LessHumid_df.head()
# Out:
#            City    Lat     Lng  Max_Temp  Humidity  Cloudiness  Wind Speed  \
# 0  nizhneudinsk  54.91   99.03    272.08        89         100        1.68
# 1         kapaa  22.08 -159.32    293.71        88          40        3.60
# 2     mount isa -20.73  139.50    294.15        19           0        5.10
# 3      bengkulu  -3.80  102.27    297.70        87          99        1.69
# 4   yellowknife  62.46 -114.35    265.93        94         100        0.45
#
#   Country        Date
# 0      RU  1604081644
# 1      US  1604081505
# 2      AU  1604081645
# 3      ID  1604081645
# 4      CA  1604081285

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
chart_title = "City Latitude vs Max Temperature (" + str(datetime.datetime.now().date()) + ")"
LessHumid_df.plot(kind="scatter", x="Lat", y="Max_Temp",s = 99, grid=True, 
              figsize=(15,10), title = chart_title, alpha = 0.8, marker="o", edgecolor = "black")
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.show()
plt.savefig(chart_title + '.jpg')

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
chart_title = "City Latitude vs Humidity (" + str(datetime.datetime.now().date()) + ")"
LessHumid_df.plot(kind="scatter", x="Lat", y="Humidity",s = 99, grid=True, 
              figsize=(15,10), title = chart_title, alpha = 0.8, marker="o", edgecolor = "black")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.show()
plt.savefig(chart_title + '.jpg')

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
chart_title = "City Latitude vs Cloudiness (" + str(datetime.datetime.now().date()) + ")"
LessHumid_df.plot(kind="scatter", x="Lat", y="Cloudiness",s = 99, grid=True, 
              figsize=(15,10), title = chart_title, alpha = 0.8, marker="o", edgecolor = "black")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.show()
plt.savefig(chart_title + '.jpg')

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
chart_title = "City Latitude vs Wind Speed (" + str(datetime.datetime.now().date()) + ")"
LessHumid_df.plot(kind="scatter", x="Lat", y="Wind Speed",s = 99, grid=True, 
              figsize=(15,10), title = chart_title, alpha = 0.8, marker="o", edgecolor = "black")
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.show()
plt.savefig(chart_title + '.jpg')

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots

# %%
# Create Northern and Southern Hemisphere DataFrames
NorthHem_df = LessHumid_df[(LessHumid_df.Lat < 0)]
NorthHem_df.head()
# Out:
#          City    Lat     Lng  Max_Temp  Humidity  Cloudiness  Wind Speed  \
# 2   mount isa -20.73  139.50    294.15        19           0        5.10
# 3    bengkulu  -3.80  102.27    297.70        87          99        1.69
# 7     ushuaia -54.80  -68.30    283.15        71          75       12.30
# 9   mahajanga -15.72   46.32    303.15        33          20        4.60
# 10    rikitea -23.12 -134.97    297.31        69          62        3.58
#
#    Country        Date
# 2       AU  1604081645
# 3       ID  1604081645
# 7       AR  1604081634
# 9       MG  1604081647
# 10      PF  1604081647

# %%
SouthHem_df = LessHumid_df[(LessHumid_df.Lat > 0)]
SouthHem_df.head()
# Out:
#            City    Lat     Lng  Max_Temp  Humidity  Cloudiness  Wind Speed  \
# 0  nizhneudinsk  54.91   99.03    272.08        89         100        1.68
# 1         kapaa  22.08 -159.32    293.71        88          40        3.60
# 4   yellowknife  62.46 -114.35    265.93        94         100        0.45
# 5        dikson  73.51   80.55    262.25        95         100       12.78
# 6      acapulco  16.86  -99.89    304.15        70          75        2.26
#
#   Country        Date
# 0      RU  1604081644
# 1      US  1604081505
# 4      CA  1604081285
# 5      RU  1604081541
# 6      MX  1604081646

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
chart_title = 'N. Hemi - Max Temp vs Latitude'

x = NorthHem_df.Lat
y = NorthHem_df.Max_Temp

(slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
regress_values = x * slope + intercept

NorthHem_df.plot(kind="scatter", x="Lat", y="Max_Temp",s = 98, grid=False, 
              figsize=(15,10), title = chart_title)


plt.plot(x, regress_values,"red")

eqn = f'y = {str(round(slope,2))}X + {str(round(intercept,2))}'
plt.annotate(eqn ,(2,2), fontsize=18,color="red")

plt.xlabel('Latitude')
plt.ylabel('Max_Temp')

plt.savefig(chart_title + '.jpg')

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
chart_title = 'S. Hemi - Max Temp vs Latitude'

x = SouthHem_df.Lat
y = SouthHem_df.Max_Temp

(slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
regress_values = x * slope + intercept

SouthHem_df.plot(kind="scatter", x="Lat", y="Max_Temp",s = 98, grid=False, 
              figsize=(15,10), title = chart_title)


plt.plot(x, regress_values,"red")

eqn = f'y = {str(round(slope,2))}X + {str(round(intercept,2))}'
plt.annotate(eqn ,(2,2), fontsize=18,color="red")

plt.xlabel('Latitude')
plt.ylabel('Max_Temp')

plt.savefig(chart_title + '.jpg')

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
chart_title = 'N. Hemi - Humidity vs Latitude'

x = NorthHem_df.Lat
y = NorthHem_df.Humidity

(slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
regress_values = x * slope + intercept

NorthHem_df.plot(kind="scatter", x="Lat", y="Humidity",s = 98, grid=False, 
              figsize=(15,10), title = chart_title)


plt.plot(x, regress_values,"red")

eqn = f'y = {str(round(slope,2))}X + {str(round(intercept,2))}'
plt.annotate(eqn ,(2,2), fontsize=18,color="red")

plt.xlabel('Latitude')
plt.ylabel('Humidity')

plt.savefig(chart_title + '.jpg')

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
chart_title = 'S. Hemi - Humidity vs Latitude'

x = SouthHem_df.Lat
y = SouthHem_df.Humidity

(slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
regress_values = x * slope + intercept

SouthHem_df.plot(kind="scatter", x="Lat", y="Humidity",s = 98, grid=False, 
              figsize=(15,10), title = chart_title)


plt.plot(x, regress_values,"red")

eqn = f'y = {str(round(slope,2))}X + {str(round(intercept,2))}'
plt.annotate(eqn ,(-10,10), fontsize=18,color="red")

plt.xlabel('Latitude')
plt.ylabel('Humidity')

plt.savefig(chart_title + '.jpg')

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
chart_title = 'N. Hemi - Cloudiness vs Latitude'

x = NorthHem_df.Lat
y = NorthHem_df.Cloudiness

(slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
regress_values = x * slope + intercept

NorthHem_df.plot(kind="scatter", x="Lat", y="Cloudiness",s = 98, grid=False, 
              figsize=(15,10), title = chart_title)


plt.plot(x, regress_values,"red")

eqn = f'y = {str(round(slope,2))}X + {str(round(intercept,2))}'
plt.annotate(eqn ,(-10,10), fontsize=18,color="red")

plt.xlabel('Latitude')
plt.ylabel('Cloudiness')

plt.savefig(chart_title + '.jpg')

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
chart_title = 'S. Hemi - Cloudiness vs Latitude'

x = SouthHem_df.Lat
y = SouthHem_df.Cloudiness

(slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
regress_values = x * slope + intercept

SouthHem_df.plot(kind="scatter", x="Lat", y="Cloudiness",s = 98, grid=False, 
              figsize=(15,10), title = chart_title)


plt.plot(x, regress_values,"red")

eqn = f'y = {str(round(slope,2))}X + {str(round(intercept,2))}'
plt.annotate(eqn ,(-10,10), fontsize=18,color="red")

plt.xlabel('Latitude')
plt.ylabel('Cloudiness')

plt.savefig(chart_title + '.jpg')

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
chart_title = 'N. Hemi - Wind Speed vs Latitude'

x = NorthHem_df.Lat
y = NorthHem_df['Wind Speed']

(slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
regress_values = x * slope + intercept

NorthHem_df.plot(kind="scatter", x="Lat", y="Wind Speed",s = 98, grid=False, 
              figsize=(15,10), title = chart_title)


plt.plot(x, regress_values,"red")

eqn = f'y = {str(round(slope,2))}X + {str(round(intercept,2))}'
plt.annotate(eqn ,(-10,10), fontsize=18,color="red")

plt.xlabel('Latitude')
plt.ylabel('Wind Speed')

plt.savefig(chart_title + '.jpg')

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
chart_title = 'S. Hemi - Wind Speed vs Latitude'

x = SouthHem_df.Lat
y = SouthHem_df['Wind Speed']

(slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
regress_values = x * slope + intercept

SouthHem_df.plot(kind="scatter", x="Lat", y="Wind Speed",s = 98, grid=False, 
              figsize=(15,10), title = chart_title)


plt.plot(x, regress_values,"red")

eqn = f'y = {str(round(slope,2))}X + {str(round(intercept,2))}'
plt.annotate(eqn ,(-10,10), fontsize=18,color="red")

plt.xlabel('Latitude')
plt.ylabel('Wind Speed')

plt.savefig(chart_title + '.jpg')

# %%
# Out:
# Collecting citipy
#   Downloading citipy-0.0.5.tar.gz (557 kB)
# Collecting kdtree>=0.12
#   Downloading kdtree-0.16-py2.py3-none-any.whl (7.7 kB)
# Building wheels for collected packages: citipy
#   Building wheel for citipy (setup.py): started
#   Building wheel for citipy (setup.py): finished with status 'done'
#   Created wheel for citipy: filename=citipy-0.0.5-py3-none-any.whl size=559707 sha256=29bf77d4209a3953e0cb5658f71fa34ec218be1dabd6582e8f8685dae8ab64c4
#   Stored in directory: c:\users\spaki\appdata\local\pip\cache\wheels\72\ae\63\5d03cf6dfe5c0e9328fb73f8b30da1948a06b9cceaf2c68d2d
# Successfully built citipy
# Installing collected packages: kdtree, citipy
# Successfully installed citipy-0.0.5 kdtree-0.16
# Note: you may need to restart the kernel to use updated packages.
